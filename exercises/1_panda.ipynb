# %% [markdown]
# ## 0. Cities in Sweden - create dataset (*)
# Create this DataFrame from scratch:
#
# Kommun	Population
# 0	Malmö	347949
# 1	Stockholm	975551
# 2	Uppsala	233839
# 3	Göteborg	583056
#   a) Use your DataFrame to print out all the cities. (*)
#
#   b) Select only the row which contains Göteborg. Do this by using the name Göteborg. (*)
#
#   c) Sort the cities by population from largest to smallest. (*)
#
#   d) Filter out the three largest cities. (*)
#
#   e) The whole population in Sweden 2020 is 10379295. Use this number to create a new column in your sorted DataFrame named: Population (%). This column should be filled with percentage of the Swedish population for each city.

# %%
import pandas as pd 

df_city = pd.DataFrame(
    {"Kommun": ["Malmö", "Stockholm", "Uppsala", "Göteborg"], "Population": [347949, 975551, 233839, 583056]})

# %%
df_city
# Out:
#       Kommun  Population
# 0      Malmö      347949
# 1  Stockholm      975551
# 2    Uppsala      233839
# 3   Göteborg      583056

# %%
df_city[df_city["Kommun"]=="Göteborg"]
# Out:
#      Kommun  Population
# 3  Göteborg      583056

# %%
df_city.sort_values(by="Population", ascending=False)
# Out:
#       Kommun  Population
# 1  Stockholm      975551
# 3   Göteborg      583056
# 0      Malmö      347949
# 2    Uppsala      233839

# %%
df_city.sort_values(by="Population", ascending=False)[:3]
# Out:
#       Kommun  Population
# 1  Stockholm      975551
# 3   Göteborg      583056
# 0      Malmö      347949

# %%
def some_func(row):
    z = row['Population']/10379295
    return z

df_city["Frak"]=df_city.apply(some_func, axis=1)

# %%
df_city
# Out:
#       Kommun  Population      Frak
# 0      Malmö      347949  0.033523
# 1  Stockholm      975551  0.093990
# 2    Uppsala      233839  0.022529
# 3   Göteborg      583056  0.056175

# %% [markdown]
# ## 1. Cities in Sweden - real dataset (*)
# Download the file komtopp50_2020.xlsx from the course github repo. The data is taken from SCB.
#
#   a) Read in the tab "Totalt" into a DataFrame and start exploring the data with some simple explorations such as
#
# df.head()
# df.info()
# df.describe()
# Feel free to do more explorations. (*)
#
#   b) Clean your data so that the head looks like this: (*)
#
# Rang 2020	Rang 2019	Kommun	Folkmängd 2020	Folkmängd 2019	Förändring
# 0	83	84	Ale	31868	31402	1.48398
# 1	64	64	Alingsås	41602	41420	0.439401
# 2	123	123	Alvesta	20224	20134	0.447005
# 3	255	255	Aneby	6821	6848	-0.394276
# 4	169	167	Arboga	14039	14087	-0.34074
#   c) Sort the cities by population from largest to smallest. (*)
#
#   d) Filter out the five smallest cities. (*)
#
#   e) Use the DataFrame to calculate Sweden's population in 2019 and 2020. (*)
#
#   f) Plot a bar chart for the five largest cities and the five smallest cities. (*)

# %%
df_kom50=pd.read_excel("../data/komtopp50_2020.xlsx", skiprows=6)

df_kom50=df_kom50.rename({"Unnamed: 2":"Kommun"}, axis=1)
df_kom50=df_kom50.rename({"2020.1": "Folkmängd 2020"},axis=1)
df_kom50=df_kom50.rename({"2019.1":"Folkmängd 2019"}, axis=1)
df_kom50=df_kom50.rename({2019:"Rang 2019"}, axis=1)
df_kom50=df_kom50.rename({2020:"Rang 2020"}, axis=1)
df_kom50=df_kom50.rename({"Unnamed: 5":"Förändring"}, axis=1)

# %%
df_kom50
# Out:
#     Rang 2020  Rang 2019        Kommun  Folkmängd 2020  Folkmängd 2019  \
# 0           1          1     Stockholm          975551          974073
# 1           2          2      Göteborg          583056          579281
# 2           3          3         Malmö          347949          344166
# 3           4          4       Uppsala          233839          230767
# 4           5          5     Linköping          164616          163051
# 5           6          6        Örebro          156381          155696
# 6           7          7      Västerås          155551          154049
# 7           8          8   Helsingborg          149280          147734
# 8           9          9    Norrköping          143478          143171
# 9          10         10     Jönköping          142427          141081
# 10         11         11          Umeå          130224          128901
# 11         12         12          Lund          125941          124935
# 12         13         13         Borås          113714          113179
# 13         14         14      Huddinge          113234          112848
# 14         15         15    Eskilstuna          106975          106859
# 15         16         16         Nacka          106505          105189
# 16         17         17      Halmstad          103754          102767
# 17         18         18         Gävle          102904          102418
# 18         19         20    Södertälje          100111           98979
# 19         20         19     Sundsvall           99439           99449
# 20         21         22         Växjö           94859           94129
# 21         22         21      Botkyrka           94847           94606
# 22         23         23      Karlstad           94828           93898
# 23         24         24       Haninge           93690           92095
# 24         25         25  Kristianstad           86217           85747
# 25         26         26    Kungsbacka           84930           84395
# 26         27         27         Solna           83162           82429
# 27         28         28      Järfälla           81274           79990
# 28         29         29         Luleå           78549           78105
# 29         30         30    Sollentuna           73990           73857
# 30         31         31    Skellefteå           72840           72589
# 31         32         32          Täby           72755           71874
# 32         33         33        Kalmar           70329           69467
# 33         34         34       Mölndal           69901           69364
# 34         35         35    Karlskrona           66515           66622
# 35         36         36       Varberg           65397           64601
# 36         37         37     Östersund           63985           63779
# 37         38         38     Norrtälje           63673           62622
# 38         39         39       Gotland           60124           59686
# 39         40         40         Falun           59528           59406
# 40         41         41   Trollhättan           59249           59058
# 41         42         43      Nyköping           57071           56591
# 42         43         44        Skövde           56791           56366
# 43         44         42     Uddevalla           56787           56703
# 44         45         45  Örnsköldsvik           55807           55998
# 45         46         47    Sundbyberg           52801           52414
# 46         47         46      Borlänge           52394           52590
# 47         48         48    Hässleholm           52010           52145
# 48         49         49       Sigtuna           49537           48964
# 49         50         50        Tyresö           48678           48333
#
#     Förändring
# 0         1478
# 1         3775
# 2         3783
# 3         3072
# 4         1565
# 5          685
# 6         1502
# 7         1546
# 8          307
# 9         1346
# 10        1323
# 11        1006
# 12         535
# 13         386
# 14         116
# 15        1316
# 16         987
# 17         486
# 18        1132
# 19         -10
# 20         730
# 21         241
# 22         930
# 23        1595
# 24         470
# 25         535
# 26         733
# 27        1284
# 28         444
# 29         133
# 30         251
# 31         881
# 32         862
# 33         537
# 34        -107
# 35         796
# 36         206
# 37        1051
# 38         438
# 39         122
# 40         191
# 41         480
# 42         425
# 43          84
# 44        -191
# 45         387
# 46        -196
# 47        -135
# 48         573
# 49         345

# %%
df_kom50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rang 2020       50 non-null     int64
#  1   Rang 2019       50 non-null     int64
#  2   Kommun          50 non-null     object
#  3   Folkmängd 2020  50 non-null     int64
#  4   Folkmängd 2019  50 non-null     int64
#  5   Förändring      50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %%
df_kom50.sort_values(by="Folkmängd 2020", ascending=False)
# Out:
#     Rang 2020  Rang 2019        Kommun  Folkmängd 2020  Folkmängd 2019  \
# 0           1          1     Stockholm          975551          974073
# 1           2          2      Göteborg          583056          579281
# 2           3          3         Malmö          347949          344166
# 3           4          4       Uppsala          233839          230767
# 4           5          5     Linköping          164616          163051
# 5           6          6        Örebro          156381          155696
# 6           7          7      Västerås          155551          154049
# 7           8          8   Helsingborg          149280          147734
# 8           9          9    Norrköping          143478          143171
# 9          10         10     Jönköping          142427          141081
# 10         11         11          Umeå          130224          128901
# 11         12         12          Lund          125941          124935
# 12         13         13         Borås          113714          113179
# 13         14         14      Huddinge          113234          112848
# 14         15         15    Eskilstuna          106975          106859
# 15         16         16         Nacka          106505          105189
# 16         17         17      Halmstad          103754          102767
# 17         18         18         Gävle          102904          102418
# 18         19         20    Södertälje          100111           98979
# 19         20         19     Sundsvall           99439           99449
# 20         21         22         Växjö           94859           94129
# 21         22         21      Botkyrka           94847           94606
# 22         23         23      Karlstad           94828           93898
# 23         24         24       Haninge           93690           92095
# 24         25         25  Kristianstad           86217           85747
# 25         26         26    Kungsbacka           84930           84395
# 26         27         27         Solna           83162           82429
# 27         28         28      Järfälla           81274           79990
# 28         29         29         Luleå           78549           78105
# 29         30         30    Sollentuna           73990           73857
# 30         31         31    Skellefteå           72840           72589
# 31         32         32          Täby           72755           71874
# 32         33         33        Kalmar           70329           69467
# 33         34         34       Mölndal           69901           69364
# 34         35         35    Karlskrona           66515           66622
# 35         36         36       Varberg           65397           64601
# 36         37         37     Östersund           63985           63779
# 37         38         38     Norrtälje           63673           62622
# 38         39         39       Gotland           60124           59686
# 39         40         40         Falun           59528           59406
# 40         41         41   Trollhättan           59249           59058
# 41         42         43      Nyköping           57071           56591
# 42         43         44        Skövde           56791           56366
# 43         44         42     Uddevalla           56787           56703
# 44         45         45  Örnsköldsvik           55807           55998
# 45         46         47    Sundbyberg           52801           52414
# 46         47         46      Borlänge           52394           52590
# 47         48         48    Hässleholm           52010           52145
# 48         49         49       Sigtuna           49537           48964
# 49         50         50        Tyresö           48678           48333
#
#     Förändring
# 0         1478
# 1         3775
# 2         3783
# 3         3072
# 4         1565
# 5          685
# 6         1502
# 7         1546
# 8          307
# 9         1346
# 10        1323
# 11        1006
# 12         535
# 13         386
# 14         116
# 15        1316
# 16         987
# 17         486
# 18        1132
# 19         -10
# 20         730
# 21         241
# 22         930
# 23        1595
# 24         470
# 25         535
# 26         733
# 27        1284
# 28         444
# 29         133
# 30         251
# 31         881
# 32         862
# 33         537
# 34        -107
# 35         796
# 36         206
# 37        1051
# 38         438
# 39         122
# 40         191
# 41         480
# 42         425
# 43          84
# 44        -191
# 45         387
# 46        -196
# 47        -135
# 48         573
# 49         345

# %%
df_kom50.sort_values(by="Folkmängd 2020", ascending=False)[-5:]
# Out:
#     Rang 2020  Rang 2019      Kommun  Folkmängd 2020  Folkmängd 2019  \
# 45         46         47  Sundbyberg           52801           52414
# 46         47         46    Borlänge           52394           52590
# 47         48         48  Hässleholm           52010           52145
# 48         49         49     Sigtuna           49537           48964
# 49         50         50      Tyresö           48678           48333
#
#     Förändring
# 45         387
# 46        -196
# 47        -135
# 48         573
# 49         345

# %%
df_kom50["Folkmängd 2019"].sum(), df_kom50["Folkmängd 2020"].sum()
# Out:
# (6187016, 6227447)

# %%
df_kom50.sort_values(by="Folkmängd 2020", ascending=False)[:5]
# Out:
#    Rang 2020  Rang 2019     Kommun  Folkmängd 2020  Folkmängd 2019  Förändring
# 0          1          1  Stockholm          975551          974073        1478
# 1          2          2   Göteborg          583056          579281        3775
# 2          3          3      Malmö          347949          344166        3783
# 3          4          4    Uppsala          233839          230767        3072
# 4          5          5  Linköping          164616          163051        1565

# %%
df_bar = df_kom50.iloc[[x for x in range(-5,5)]]

# %%
df_bar
# Out:
#     Rang 2020  Rang 2019      Kommun  Folkmängd 2020  Folkmängd 2019  \
# 45         46         47  Sundbyberg           52801           52414
# 46         47         46    Borlänge           52394           52590
# 47         48         48  Hässleholm           52010           52145
# 48         49         49     Sigtuna           49537           48964
# 49         50         50      Tyresö           48678           48333
# 0           1          1   Stockholm          975551          974073
# 1           2          2    Göteborg          583056          579281
# 2           3          3       Malmö          347949          344166
# 3           4          4     Uppsala          233839          230767
# 4           5          5   Linköping          164616          163051
#
#     Förändring
# 45         387
# 46        -196
# 47        -135
# 48         573
# 49         345
# 0         1478
# 1         3775
# 2         3783
# 3         3072
# 4         1565

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.bar(df_bar["Kommun"],df_bar["Folkmängd 2019"])
plt.xticks(rotation=30, ha='right')
plt.ylabel('Million')
plt.yticks([0, 250000, 500000, 1000000])
# Out:
# ([<matplotlib.axis.YTick at 0x1e395a3b590>,
#   <matplotlib.axis.YTick at 0x1e395a38f50>,
#   <matplotlib.axis.YTick at 0x1e390e9b710>,
#   <matplotlib.axis.YTick at 0x1e394f5b410>],
#  [Text(0, 0, '0.00'),
#   Text(0, 250000, '0.25'),
#   Text(0, 500000, '0.50'),
#   Text(0, 1000000, '1.00')])

# %% [markdown]
# ## We continue with the same Excel-file as in task 2, but now you should also read in the sheets "Kvinnor" and "Män" into two additional DataFrames. In this task, many operations are similar to all three datasets, try creating custom made functions to reuse as much code as possible.
#
#   a) Clean your data so that the head looks like this: (*)
#
# Male:
#
# Rang 2020	Rang 2019	Kommun	Folkmängd 2020	Folkmängd 2019	Förändring	Kön
# 0	81	83	Ale	16256	16054	1.25825	Man
# 1	64	64	Alingsås	20702	20646	0.271239	Man
# 2	122	123	Alvesta	10367	10339	0.270819	Man
# 3	255	255	Aneby	3503	3498	0.142939	Man
# 4	169	168	Arboga	7094	7114	-0.281136	Man
# Female:
#
# Rang 2020	Rang 2019	Kommun	Folkmängd 2020	Folkmängd 2019	Förändring	Kön
# 0	84	85	Ale	15612	15348	1.72009	Kvinna
# 1	64	64	Alingsås	20900	20774	0.606527	Kvinna
# 2	123	123	Alvesta	9857	9795	0.632976	Kvinna
# 3	255	255	Aneby	3318	3350	-0.955224	Kvinna
# 4	165	164	Arboga	6945	6973	-0.401549	Kvinna
#   b) Merge the male and female DataFrames vertically and set index to "Kommun". Note that there now should be 580 rows now. (*)
#
# Kommun	Folkmängd 2020	Folkmängd 2019	Förändring	Kön
# Ale	16256	16054	1.25825	Man
# Alingsås	20702	20646	0.271239	Man
# ...	...	...	...	...
# Överkalix	1559	1578	-1.20406	Kvinna
# Övertorneå	2027	2065	-1.84019	Kvinna
#   c) Extract and change column name from the total DataFrame so that the head look like this: (*)
#
# Kommun	Total Pop 2020	Total Pop 2019	Total förändring
# 0	Ale	31868	31402	1.48398
# 1	Alingsås	41602	41420	0.439401
# 2	Alvesta	20224	20134	0.447005
# 3	Aneby	6821	6848	-0.394276
# 4	Arboga	14039	14087	-0.34074
#   d) Merge this data with the data in b) so that the head look like this: (*)
#
# Kommun	Folkmängd 2020	Folkmängd 2019	Förändring	Kön	Total Pop 2020	Total Pop 2019	Total förändring
# Stockholm	482982	482220	0.158019	Man	975551	974073	0.151734
# Stockholm	492569	491853	0.145572	Kvinna	975551	974073	0.151734
# Göteborg	292505	290308	0.756782	Man	583056	579281	0.65167
# Göteborg	290551	288973	0.546072	Kvinna	583056	579281	0.65167
# Malmö	175411	173543	1.07639	Kvinna	347949	344166	1.09918
#   e) Create barplots showing the gender populations of Swedens 10 largest and 10 smallest cities. (*)
#
#   f) Create a pie chart showing the total male and female population in Sweden 2020. (*)
#
#   g) Create a barplot showing the cities with the five largest percentual gender difference in 2020. (**)
#
#   h) Create a barplot showing the top 5 cities with largest populational growth from 2019 to 2020 (**)
#
#   i) Feel free to investigate other questions you are interested in using these datasets. (*), (**)

# %%
df_kom50_fem=pd.read_excel("../data/komtopp50_2020.xlsx", skiprows=6, sheet_name="Kvinnor")
df_kom50_mal=pd.read_excel("../data/komtopp50_2020.xlsx", skiprows=6, sheet_name="Män")
df_kom50_fem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   2020        290 non-null    int64
#  1   2019        290 non-null    int64
#  2   Unnamed: 2  290 non-null    object
#  3   2020.1      290 non-null    int64
#  4   2019.1      290 non-null    int64
#  5   %           290 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 13.7+ KB

# %%
def kvinna(row):
    return "Kvinna"

def man(row):
    return "Man"

def headinfo(df):
    df=df.rename({"Unnamed: 2":"Kommun"}, axis=1)
    df=df.rename({"2020.1": "Folkmängd 2020"},axis=1)
    df=df.rename({"2019.1":"Folkmängd 2019"}, axis=1)
    df=df.rename({2019:"Rang 2019"}, axis=1)
    df=df.rename({2020:"Rang 2020"}, axis=1)
    df=df.rename({"%":"Förändring"}, axis=1)
    return df

df_fem=headinfo(df_kom50_fem)
df_fem["Kön"]=df_fem.apply(kvinna, axis=1)


df_mal=headinfo(df_kom50_mal)
df_mal["Kön"]=df_mal.apply(man,axis=1)

# %%
df_all = pd.concat([df_mal, df_fem])[['Kommun','Folkmängd 2020','Folkmängd 2019','Förändring','Kön']]
df_all.set_index('Kommun')
# Out:
#               Folkmängd 2020  Folkmängd 2019 Förändring     Kön
# Kommun
# Ale                    16256           16054   1.258253     Man
# Alingsås               20702           20646   0.271239     Man
# Alvesta                10367           10339   0.270819     Man
# Aneby                   3503            3498   0.142939     Man
# Arboga                  7094            7114  -0.281136     Man
# ...                      ...             ...        ...     ...
# Österåker              22997           22442   2.473042  Kvinna
# Östhammar              10846           10803   0.398038  Kvinna
# Östra Göinge            7270            7262   0.110162  Kvinna
# Överkalix               1559            1578  -1.204056  Kvinna
# Övertorneå              2027            2065  -1.840194  Kvinna
#
# [580 rows x 4 columns]

# %%
df_total=df_kom50.rename({"Folkmängd 2020":"Total Pop 2020"}, axis=1)
df_total=df_total.rename({"Folkmängd 2019":"Total Pop 2019"}, axis=1)
df_total=df_total.rename({"Förändring": "Total förändring"},axis=1)
df_total = df_total[['Kommun','Total Pop 2020','Total Pop 2019','Total förändring']]
#Kommun	Total Pop 2020	Total Pop 2019	Total förändring

# %%
df_total.head()
# Out:
#       Kommun  Total Pop 2020  Total Pop 2019  Total förändring
# 0  Stockholm          975551          974073              1478
# 1   Göteborg          583056          579281              3775
# 2      Malmö          347949          344166              3783
# 3    Uppsala          233839          230767              3072
# 4  Linköping          164616          163051              1565

# %%
df_plot=pd.merge(left= df_total,right=df_all, on=['Kommun'])

# %%
df_plot
# Out:
#         Kommun  Total Pop 2020  Total Pop 2019  Total förändring  \
# 0    Stockholm          975551          974073              1478
# 1    Stockholm          975551          974073              1478
# 2     Göteborg          583056          579281              3775
# 3     Göteborg          583056          579281              3775
# 4        Malmö          347949          344166              3783
# ..         ...             ...             ...               ...
# 95  Hässleholm           52010           52145              -135
# 96     Sigtuna           49537           48964               573
# 97     Sigtuna           49537           48964               573
# 98      Tyresö           48678           48333               345
# 99      Tyresö           48678           48333               345
#
#     Folkmängd 2020  Folkmängd 2019 Förändring     Kön
# 0           482982          482220   0.158019     Man
# 1           492569          491853   0.145572  Kvinna
# 2           292505          290308   0.756782     Man
# 3           290551          288973   0.546072  Kvinna
# 4           172538          170623   1.122357     Man
# ..             ...             ...        ...     ...
# 95           25840           25863   -0.08893  Kvinna
# 96           25246           24972   1.097229     Man
# 97           24291           23992   1.246249  Kvinna
# 98           24305           24254   0.210275     Man
# 99           24373           24079   1.220981  Kvinna
#
# [100 rows x 8 columns]

# %%
# Pivot the DataFrame to get separate columns for 'Man' and 'Kvinna'
select = df_plot.sort_values(by="Total Pop 2020").iloc[[x for x in range(-10,10)]]


df_pivot = select.pivot(index='Kommun', columns='Kön', values='Folkmängd 2019')

# Plotting the grouped bar chart
ax = df_pivot.plot(kind='bar', stacked=False, figsize=(10, 6))

# Adding labels and title
plt.xlabel('Kommun')
plt.ylabel('Population 2019')
plt.title('Population 2019 by Kommun and Kön')

# Display the plot
plt.show()

# %%
gender_counts = df_plot['Kön'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral'])
plt.title('Gender Distribution')

# Display the plot
plt.show()

# %%
def fraction_sex(row):
    z = row['Folkmängd 2020']/row['Total Pop 2020']
    return z

df_plot["Gen_diff"]=df_plot.apply(fraction_sex, axis=1)

gendiff=df_plot.sort_values(by="Gen_diff", ascending=False)

top5=gendiff[:5]

# %%
top5
df_pl2=pd.merge(left=df_plot,right=top5["Kommun"], how="inner")

df_pivot = df_pl2.pivot(index='Kommun', columns='Kön', values='Folkmängd 2019')

# Plotting the grouped bar chart
ax = df_pivot.plot(kind='bar', stacked=False, figsize=(10, 6))

# Adding labels and title
plt.xlabel('Kommun')
plt.ylabel('Population 2020')
plt.title('Largest differences in sex')

# Display the plot
plt.show()

# %%
# Largest population growth

def pop_growth(row):
    z = row['Total förändring']/row['Total Pop 2020']
    return z

df_plot["Pop_growth"]=df_plot.apply(pop_growth, axis=1)

growing=df_total.sort_values(by="Total förändring", ascending=False)[:5]
grow2=df_plot.sort_values(by="Pop_growth", ascending=False)[:5]

# %%
growing, grow2
# Out:
# (       Kommun  Total Pop 2020  Total Pop 2019  Total förändring
#  2       Malmö          347949          344166              3783
#  1    Göteborg          583056          579281              3775
#  3     Uppsala          233839          230767              3072
#  23    Haninge           93690           92095              1595
#  4   Linköping          164616          163051              1565,
#         Kommun  Total Pop 2020  Total Pop 2019  Total förändring  \
#  47    Haninge           93690           92095              1595
#  46    Haninge           93690           92095              1595
#  74  Norrtälje           63673           62622              1051
#  75  Norrtälje           63673           62622              1051
#  55   Järfälla           81274           79990              1284
#
#      Folkmängd 2020  Folkmängd 2019 Förändring     Kön  Gen_diff  Pop_growth
#  47           45946           45173   1.711199  Kvinna  0.490405    0.017024
#  46           47744           46922   1.751843     Man  0.509595    0.017024
#  74           32198           31688   1.609442     Man  0.505677    0.016506
#  75           31475           30934   1.748885  Kvinna  0.494323    0.016506
#  55           40018           39431   1.488676  Kvinna  0.492384    0.015798  )
